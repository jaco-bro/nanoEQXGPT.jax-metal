# %%
# !python train.py config/train_tinystories.py --out_path="out-tinystories/model.eqx" --max_iters=250
# Out:
# Overriding config with config/train_tinystories.py:
# # train a miniature character-level shakespeare model
# # good for debugging and playing on macbooks and such
#
# out_path = 'out-tinystories/model.eqx'
# eval_interval = 250 # keep frequent because we'll overfit
# eval_iters = 20
# log_interval = 5 # don't print too too often
#
# # we expect to overfit on this small dataset, so only save when val improves
# always_save_checkpoint = False
#
# wandb_log = False # override via command line if you like
#
# dataset = 'tinystories'
# gradient_accumulation_steps = 1
# batch_size = 32
# block_size = 100 # context of up to 256 previous characters
#
# # baby GPT model :)
# n_layer = 16
# n_head = 12
# n_embd = 512
# dropout = 0.0
#
# learning_rate = 1e-4 # with baby networks can afford to go a bit higher
# max_iters = 500
# lr_decay_iters = 500 # make equal to max_iters usually
# min_lr = 1e-5 # learning_rate / 10 usually
# beta2 = 0.99 # make a bit bigger because number of tokens per iter is small
#
# warmup_iters = 100 # not super necessary potentially
#
# # on macbook also add
# # device = 'cpu'  # run on cpu only
# # compile = False # do not torch compile the model
# Overriding: out_path = out-tinystories/model.eqx
# Overriding: max_iters = 250
# ✅ Output dir created !
# Initializing a new model from scratch
# defaulting to vocab_size of GPT-2 to 50304 (50257 rounded up for efficiency)
# ✅ Model initialized !
# ✅ Optimizer initialized !
# 👀 Starting run !
# saving checkpoint to out-tinystories/model.eqx
# iter 0: loss 11.0042, time 18803.85ms, mfu -100.00%
# iter 5: loss 9.5852, time 474.64ms, mfu -100.00%
# iter 10: loss 8.9671, time 356.44ms, mfu -100.00%
# iter 15: loss 8.6378, time 354.95ms, mfu -100.00%
# iter 20: loss 8.2421, time 367.24ms, mfu -100.00%
# iter 25: loss 7.8830, time 431.74ms, mfu -100.00%
# iter 30: loss 7.4266, time 381.58ms, mfu -100.00%
# iter 35: loss 7.2114, time 356.30ms, mfu -100.00%
# iter 40: loss 6.9484, time 354.93ms, mfu -100.00%
# iter 45: loss 6.5975, time 355.89ms, mfu -100.00%
# iter 50: loss 6.4266, time 362.41ms, mfu -100.00%
# iter 55: loss 6.1902, time 379.77ms, mfu -100.00%
# iter 60: loss 6.0758, time 551.73ms, mfu -100.00%
# iter 65: loss 5.9377, time 433.12ms, mfu -100.00%
# iter 70: loss 5.7522, time 358.60ms, mfu -100.00%
# iter 75: loss 5.7877, time 383.14ms, mfu -100.00%
# iter 80: loss 5.6620, time 379.10ms, mfu -100.00%
# iter 85: loss 5.4627, time 358.37ms, mfu -100.00%
# iter 90: loss 5.4064, time 392.63ms, mfu -100.00%
# iter 95: loss 5.3465, time 445.69ms, mfu -100.00%
# iter 100: loss 5.2727, time 448.81ms, mfu -100.00%
# iter 105: loss 5.3902, time 444.69ms, mfu -100.00%
# iter 110: loss 5.2393, time 447.00ms, mfu -100.00%
# iter 115: loss 5.2331, time 459.38ms, mfu -100.00%
# iter 120: loss 5.0284, time 356.83ms, mfu -100.00%
# iter 125: loss 5.0517, time 432.16ms, mfu -100.00%
# iter 130: loss 4.9906, time 481.60ms, mfu -100.00%
# iter 135: loss 5.0370, time 367.40ms, mfu -100.00%
# iter 140: loss 5.0347, time 368.88ms, mfu -100.00%
# iter 145: loss 5.0160, time 364.19ms, mfu -100.00%
# iter 150: loss 5.0095, time 418.15ms, mfu -100.00%
# iter 155: loss 4.9270, time 396.23ms, mfu -100.00%
# iter 160: loss 4.9025, time 357.46ms, mfu -100.00%
# iter 165: loss 4.8370, time 470.23ms, mfu -100.00%
# iter 170: loss 4.8548, time 445.75ms, mfu -100.00%
# iter 175: loss 4.8847, time 397.24ms, mfu -100.00%
# iter 180: loss 4.7403, time 364.39ms, mfu -100.00%
# iter 185: loss 4.7665, time 552.94ms, mfu -100.00%
# iter 190: loss 4.6535, time 358.78ms, mfu -100.00%
# iter 195: loss 4.7696, time 366.80ms, mfu -100.00%
# iter 200: loss 4.6237, time 560.85ms, mfu -100.00%
# iter 205: loss 4.5199, time 356.60ms, mfu -100.00%
# iter 210: loss 4.6069, time 355.79ms, mfu -100.00%
# iter 215: loss 4.6391, time 355.48ms, mfu -100.00%
# iter 220: loss 4.4612, time 368.38ms, mfu -100.00%
# iter 225: loss 4.5680, time 368.91ms, mfu -100.00%
# iter 230: loss 4.4612, time 359.97ms, mfu -100.00%
# iter 235: loss 4.5428, time 354.46ms, mfu -100.00%
# iter 240: loss 4.5607, time 370.73ms, mfu -100.00%
# iter 245: loss 4.4745, time 355.56ms, mfu -100.00%
# saving checkpoint to out-tinystories/model.eqx
# iter 250: loss 4.5061, time 4857.09ms, mfu -100.00%

# %%
import json
import os
from model import GPT, GPTConfig
import equinox as eqx
import jax
import jax.tree_util as jtu

def load(filename):
    with open(filename, "rb") as f:
        checkpoint_params = json.loads(f.readline().decode())
        gptconf = GPTConfig(**checkpoint_params["model_args"])
        return (
            eqx.tree_deserialise_leaves(
                f, GPT.create_instance(gptconf, key=jax.random.key(1))
            ),
            checkpoint_params,
        )
        
        
model, checkpoint_params = load("out-tinystories/model.eqx")

def model_surgery(path, x):
    if "wte.weight" in jax.tree_util.keystr(path):
        return jax.random.normal(jax.random.key(1), shape=x.shape)
    return x

model = jtu.tree_map_with_path(model_surgery, model)
print(checkpoint_params)
def save(filename, hyperparams, model):
    with open(filename, "wb") as f:
        hyperparam_str = json.dumps(hyperparams)
        f.write((hyperparam_str + "\n").encode())
        eqx.tree_serialise_leaves(f, model)

save("out-tinystories/model2.eqx", checkpoint_params, model)
# Out:
# {'model_args': {'n_layer': 16, 'n_head': 12, 'n_embd': 512, 'block_size': 100, 'bias': False, 'vocab_size': 50304, 'dropout': 0.0}, 'config': {'out_path': 'out-tinystories/model.eqx', 'eval_interval': 250, 'log_interval': 5, 'eval_iters': 20, 'eval_only': False, 'always_save_checkpoint': False, 'init_from': 'scratch', 'wandb_log': False, 'tensorboard_log': True, 'log_project': 'exp1', 'log_run_name': 'gpt2', 'dataset': 'tinystories', 'gradient_accumulation_steps': 1, 'batch_size': 32, 'block_size': 100, 'n_layer': 16, 'n_head': 12, 'n_embd': 512, 'dropout': 0.0, 'bias': False, 'learning_rate': 0.0001, 'max_iters': 250, 'weight_decay': 0.1, 'beta1': 0.9, 'beta2': 0.99, 'grad_clip': 1.0, 'decay_lr': True, 'warmup_iters': 100, 'lr_decay_iters': 500, 'min_lr': 1e-05, 'backend': 'nccl', 'device': 'cuda', 'dtype': 'bfloat16', 'seed': 1}}

# %%
# !python3 train.py config/train_tinystories.py --init_from="resume" --out_path="out-tinystories/model2.eqx" --max_iters=250
# Out:
# Overriding config with config/train_tinystories.py:
# # train a miniature character-level shakespeare model
# # good for debugging and playing on macbooks and such
#
# out_path = 'out-tinystories/model.eqx'
# eval_interval = 250 # keep frequent because we'll overfit
# eval_iters = 20
# log_interval = 5 # don't print too too often
#
# # we expect to overfit on this small dataset, so only save when val improves
# always_save_checkpoint = False
#
# wandb_log = False # override via command line if you like
#
# dataset = 'tinystories'
# gradient_accumulation_steps = 1
# batch_size = 32
# block_size = 100 # context of up to 256 previous characters
#
# # baby GPT model :)
# n_layer = 16
# n_head = 12
# n_embd = 512
# dropout = 0.0
#
# learning_rate = 1e-4 # with baby networks can afford to go a bit higher
# max_iters = 500
# lr_decay_iters = 500 # make equal to max_iters usually
# min_lr = 1e-5 # learning_rate / 10 usually
# beta2 = 0.99 # make a bit bigger because number of tokens per iter is small
#
# warmup_iters = 100 # not super necessary potentially
#
# # on macbook also add
# # device = 'cpu'  # run on cpu only
# # compile = False # do not torch compile the model
# Overriding: init_from = resume
# Overriding: out_path = out-tinystories/model2.eqx
# Overriding: max_iters = 250
# ✅ Output dir created !
# Resuming training from out-tinystories/model2.eqx
# ✅ Model initialized !
# ✅ Optimizer initialized !
# 👀 Starting run !
# saving checkpoint to out-tinystories/model2.eqx
# iter 0: loss 6.9140, time 19093.21ms, mfu -100.00%
# iter 5: loss 5.7929, time 368.12ms, mfu -100.00%
# iter 10: loss 5.6044, time 364.51ms, mfu -100.00%
# iter 15: loss 5.4370, time 363.56ms, mfu -100.00%
# iter 20: loss 5.2008, time 411.12ms, mfu -100.00%
# iter 25: loss 5.0423, time 359.04ms, mfu -100.00%
# iter 30: loss 5.0086, time 360.76ms, mfu -100.00%
# iter 35: loss 4.9473, time 361.44ms, mfu -100.00%
# iter 40: loss 4.8614, time 364.98ms, mfu -100.00%
# iter 45: loss 4.8032, time 360.84ms, mfu -100.00%
# iter 50: loss 4.6810, time 355.93ms, mfu -100.00%
# iter 55: loss 4.6033, time 361.80ms, mfu -100.00%
# iter 60: loss 4.6901, time 436.31ms, mfu -100.00%
# iter 65: loss 4.6341, time 351.15ms, mfu -100.00%
# iter 70: loss 4.6238, time 357.72ms, mfu -100.00%
# iter 75: loss 4.5515, time 362.86ms, mfu -100.00%
# iter 80: loss 4.4238, time 358.69ms, mfu -100.00%
# iter 85: loss 4.4526, time 419.64ms, mfu -100.00%
# iter 90: loss 4.4844, time 354.38ms, mfu -100.00%
# iter 95: loss 4.3842, time 354.22ms, mfu -100.00%
# iter 100: loss 4.4203, time 401.75ms, mfu -100.00%
# iter 105: loss 4.6856, time 360.92ms, mfu -100.00%
# iter 110: loss 4.5854, time 357.36ms, mfu -100.00%
# iter 115: loss 4.4289, time 356.97ms, mfu -100.00%
# iter 120: loss 4.3875, time 378.64ms, mfu -100.00%
# iter 125: loss 4.3491, time 358.75ms, mfu -100.00%
# iter 130: loss 4.2718, time 353.50ms, mfu -100.00%
# iter 135: loss 4.4314, time 360.55ms, mfu -100.00%
# iter 140: loss 4.3632, time 363.65ms, mfu -100.00%
# iter 145: loss 4.3377, time 362.97ms, mfu -100.00%
# iter 150: loss 4.1986, time 357.40ms, mfu -100.00%
# iter 155: loss 4.3007, time 358.81ms, mfu -100.00%
# iter 160: loss 4.2426, time 354.12ms, mfu -100.00%
# iter 165: loss 4.4462, time 358.04ms, mfu -100.00%
# iter 170: loss 4.3340, time 356.38ms, mfu -100.00%
# iter 175: loss 4.3723, time 360.89ms, mfu -100.00%
# iter 180: loss 4.1789, time 356.39ms, mfu -100.00%
# iter 185: loss 4.3124, time 363.06ms, mfu -100.00%
# iter 190: loss 4.1350, time 352.45ms, mfu -100.00%
# iter 195: loss 4.2674, time 357.21ms, mfu -100.00%
# iter 200: loss 4.2081, time 358.95ms, mfu -100.00%
# iter 205: loss 4.2067, time 435.70ms, mfu -100.00%
# iter 210: loss 4.0980, time 411.72ms, mfu -100.00%
# iter 215: loss 4.3224, time 387.02ms, mfu -100.00%
# iter 220: loss 4.3119, time 379.31ms, mfu -100.00%
# iter 225: loss 4.2530, time 355.63ms, mfu -100.00%
# iter 230: loss 4.3999, time 353.29ms, mfu -100.00%
# iter 235: loss 4.3009, time 355.80ms, mfu -100.00%
# iter 240: loss 4.0783, time 436.14ms, mfu -100.00%
# iter 245: loss 4.1678, time 382.19ms, mfu -100.00%
# saving checkpoint to out-tinystories/model2.eqx
# iter 250: loss 4.1016, time 4971.60ms, mfu -100.00%

# %%
import json
import os
from model import GPT, GPTConfig
import equinox as eqx
import jax
import jax.tree_util as jtu

def load(filename):
    with open(filename, "rb") as f:
        checkpoint_params = json.loads(f.readline().decode())
        gptconf = GPTConfig(**checkpoint_params["model_args"])
        return (
            eqx.tree_deserialise_leaves(
                f, GPT.create_instance(gptconf, key=jax.random.key(1))
            ),
            checkpoint_params,
        )
        
        
model, checkpoint_params = load("out-tinystories/model2.eqx")

def model_surgery(path, x):
    if "wte.weight" in jax.tree_util.keystr(path):
        return jax.random.normal(jax.random.key(2), shape=x.shape)
    return x

model = jtu.tree_map_with_path(model_surgery, model)
print(checkpoint_params)
def save(filename, hyperparams, model):
    with open(filename, "wb") as f:
        hyperparam_str = json.dumps(hyperparams)
        f.write((hyperparam_str + "\n").encode())
        eqx.tree_serialise_leaves(f, model)

save("out-tinystories/model3.eqx", checkpoint_params, model)
# Out:
# {'model_args': {'n_layer': 16, 'n_head': 12, 'n_embd': 512, 'block_size': 100, 'bias': False, 'vocab_size': 50304, 'dropout': 0.0}, 'config': {'out_path': 'out-tinystories/model2.eqx', 'eval_interval': 250, 'log_interval': 5, 'eval_iters': 20, 'eval_only': False, 'always_save_checkpoint': False, 'init_from': 'resume', 'wandb_log': False, 'tensorboard_log': True, 'log_project': 'exp1', 'log_run_name': 'gpt2', 'dataset': 'tinystories', 'gradient_accumulation_steps': 1, 'batch_size': 32, 'block_size': 100, 'n_layer': 16, 'n_head': 12, 'n_embd': 512, 'dropout': 0.0, 'bias': False, 'learning_rate': 0.0001, 'max_iters': 250, 'weight_decay': 0.1, 'beta1': 0.9, 'beta2': 0.99, 'grad_clip': 1.0, 'decay_lr': True, 'warmup_iters': 100, 'lr_decay_iters': 500, 'min_lr': 1e-05, 'backend': 'nccl', 'device': 'cuda', 'dtype': 'bfloat16', 'seed': 1}}

# %%
# !python3 train.py config/train_tinystories.py --init_from="resume" --out_path="out-tinystories/model3.eqx" --max_iters=250
# Out:
# Overriding config with config/train_tinystories.py:
# # train a miniature character-level shakespeare model
# # good for debugging and playing on macbooks and such
#
# out_path = 'out-tinystories/model.eqx'
# eval_interval = 250 # keep frequent because we'll overfit
# eval_iters = 20
# log_interval = 5 # don't print too too often
#
# # we expect to overfit on this small dataset, so only save when val improves
# always_save_checkpoint = False
#
# wandb_log = False # override via command line if you like
#
# dataset = 'tinystories'
# gradient_accumulation_steps = 1
# batch_size = 32
# block_size = 100 # context of up to 256 previous characters
#
# # baby GPT model :)
# n_layer = 16
# n_head = 12
# n_embd = 512
# dropout = 0.0
#
# learning_rate = 1e-4 # with baby networks can afford to go a bit higher
# max_iters = 500
# lr_decay_iters = 500 # make equal to max_iters usually
# min_lr = 1e-5 # learning_rate / 10 usually
# beta2 = 0.99 # make a bit bigger because number of tokens per iter is small
#
# warmup_iters = 100 # not super necessary potentially
#
# # on macbook also add
# # device = 'cpu'  # run on cpu only
# # compile = False # do not torch compile the model
# Overriding: init_from = resume
# Overriding: out_path = out-tinystories/model3.eqx
# Overriding: max_iters = 250
# ✅ Output dir created !
# Resuming training from out-tinystories/model3.eqx
# ✅ Model initialized !
# ✅ Optimizer initialized !
# 👀 Starting run !
# saving checkpoint to out-tinystories/model3.eqx
# iter 0: loss 4.1593, time 18729.55ms, mfu -100.00%
# iter 5: loss 4.1835, time 354.20ms, mfu -100.00%
# iter 10: loss 4.1121, time 353.62ms, mfu -100.00%
# iter 15: loss 4.2373, time 353.69ms, mfu -100.00%
# iter 20: loss 3.9901, time 357.92ms, mfu -100.00%
# iter 25: loss 4.1480, time 360.31ms, mfu -100.00%
# iter 30: loss 4.1114, time 370.16ms, mfu -100.00%
# iter 35: loss 4.0049, time 419.85ms, mfu -100.00%
# iter 40: loss 4.1063, time 346.77ms, mfu -100.00%
# ^C
# Traceback (most recent call last):
#   File "/home/tugdual/nanoEQXGPT/train.py", line 313, in <module>
#     updates, optimizer_state = optimizer.update(
#   File "/home/tugdual/miniconda3/envs/xtts/lib/python3.10/site-packages/optax/schedules/_inject.py", line 196, in update_fn
#     updates, inner_state = base.with_extra_args_support(
#   File "/home/tugdual/miniconda3/envs/xtts/lib/python3.10/site-packages/optax/transforms/_combining.py", line 75, in update_fn
#     updates, new_s = fn(updates, s, params, **extra_args)
#   File "/home/tugdual/miniconda3/envs/xtts/lib/python3.10/site-packages/optax/_src/base.py", line 333, in update
#     return tx.update(updates, state, params)
#   File "/home/tugdual/miniconda3/envs/xtts/lib/python3.10/site-packages/optax/_src/transform.py", line 285, in update_fn
#     nu = otu.tree_update_moment_per_elem_norm(updates, state.nu, b2, 2)
#   File "/home/tugdual/miniconda3/envs/xtts/lib/python3.10/site-packages/optax/tree_utils/_tree_math.py", line 341, in tree_update_moment_per_elem_norm
#     return jax.tree.map(
#   File "/home/tugdual/miniconda3/envs/xtts/lib/python3.10/site-packages/jax/_src/tree.py", line 155, in map
#     return tree_util.tree_map(f, tree, *rest, is_leaf=is_leaf)
#   File "/home/tugdual/miniconda3/envs/xtts/lib/python3.10/site-packages/jax/_src/tree_util.py", line 344, in tree_map
#     return treedef.unflatten(f(*xs) for xs in zip(*all_leaves))
#   File "/home/tugdual/miniconda3/envs/xtts/lib/python3.10/site-packages/jax/_src/tree_util.py", line 344, in <genexpr>
#     return treedef.unflatten(f(*xs) for xs in zip(*all_leaves))
#   File "/home/tugdual/miniconda3/envs/xtts/lib/python3.10/site-packages/optax/tree_utils/_tree_math.py", line 343, in <lambda>
#     (1 - decay) * orderth_norm(g) + decay * t if g is not None else None
#   File "/home/tugdual/miniconda3/envs/xtts/lib/python3.10/site-packages/jax/_src/numpy/array_methods.py", line 573, in deferring_binary_op
#     return binary_op(*args)
#   File "/home/tugdual/miniconda3/envs/xtts/lib/python3.10/site-packages/jax/_src/numpy/ufunc_api.py", line 177, in __call__
#     return call(*args)
# KeyboardInterrupt
